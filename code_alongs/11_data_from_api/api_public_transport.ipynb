# %% [markdown]
# # EDA om trafiklab resrobot API

# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv()

API_KEY = os.getenv("API_KEY")

url = f"https://api.resrobot.se/v2.1/trip?format=json&originId=740000002&destId=740000003&passlist=true&showPassingPoints=true&accessId={API_KEY}"

response = requests.get(url)
result = response.json()
result.keys()
# Out:
# dict_keys(['Trip', 'ResultStatus', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'planRtTs', 'requestId', 'scrB', 'scrF'])

# %%
result["Trip"]
# Out:
# [{'Origin': {'name': 'Göteborg Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#    'extId': '740000002',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '11:40:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'routeIdx': 12,
#    'prognosisType': 'PROGNOSED',
#    'time': '14:48:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2024-12-11',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '7. jan t o m 8. jun 2025; utom 12. t o m 21. apr 2025, 26. apr',
#     'sDaysB': 'FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFC00F7FFFFFFFFFF000'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Göteborg Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'routeIdx': 0,
#       'prognosisType': 'PROGNOSED',
#       'time': '11:40:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'routeIdx': 12,
#       'prognosisType': 'PROGNOSED',
#       'time': '14:48:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'Notes': {'Note': [{'value': 'Ej reservering',
#         'key': 'AE',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 12,
#         'txtN': 'Ej reservering'},
#        {'value': 'Rullstolslyft',
#         'key': 'AN',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 12,
#         'txtN': 'Rullstolslyft'},
#        {'value': 'EU förordning 2021/782',
#         'key': 'EJ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 12,
#         'txtN': 'EU förordning 2021/782'}]},
#      'JourneyDetailRef': {'ref': '1|135397|5|1|7012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'Öresundståg',
#         'nameS': '300',
#         'nameN': '300',
#         'nameL': 'Öresundståg',
#         'id': '300'},
#        'name': 'Regional Tåg 1087',
#        'internalName': 'Regional Tåg 1087',
#        'displayNumber': '1087',
#        'num': '1087',
#        'line': '1087',
#        'lineId': '1300080400030',
#        'catOut': 'JRE',
#        'catIn': 'JRE',
#        'catCode': '2',
#        'cls': '4',
#        'catOutS': 'JRE',
#        'catOutL': 'Regional Tåg',
#        'operatorCode': '300',
#        'operator': 'Öresundståg',
#        'admin': '300___',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 12,
#        'matchId': '11159;804;1087'}],
#      'Stops': {'Stop': [{'name': 'Göteborg Centralstation',
#         'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#         'extId': '740000002',
#         'routeIdx': 0,
#         'lon': 11.973479,
#         'lat': 57.708895,
#         'depPrognosisType': 'PROGNOSED',
#         'depTime': '11:40:00',
#         'depDate': '2025-01-07',
#         'depDir': 'Köpenhamn Österport (Danmark)',
#         'minimumChangeDuration': 'PT15M'},
#        {'name': 'Mölndal station',
#         'id': 'A=1@O=Mölndal station@X=12018722@Y=57655958@U=1@L=740000315@',
#         'extId': '740000315',
#         'routeIdx': 1,
#         'lon': 12.018722,
#         'lat': 57.655958,
#         'depTime': '11:48:00',
#         'depDate': '2025-01-07',
#         'arrTime': '11:48:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Kungsbacka station',
#         'id': 'A=1@O=Kungsbacka station@X=12079614@Y=57490556@U=1@L=740000161@',
#         'extId': '740000161',
#         'routeIdx': 2,
#         'lon': 12.079614,
#         'lat': 57.490556,
#         'depTime': '11:59:00',
#         'depDate': '2025-01-07',
#         'arrTime': '11:59:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Varberg station',
#         'id': 'A=1@O=Varberg station@X=12248081@Y=57109378@U=1@L=740000110@',
#         'extId': '740000110',
#         'routeIdx': 3,
#         'lon': 12.248081,
#         'lat': 57.109378,
#         'depTime': '12:29:00',
#         'depDate': '2025-01-07',
#         'arrTime': '12:25:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Falkenberg station',
#         'id': 'A=1@O=Falkenberg station@X=12507555@Y=56919768@U=1@L=740001579@',
#         'extId': '740001579',
#         'routeIdx': 4,
#         'lon': 12.507555,
#         'lat': 56.919768,
#         'depTime': '12:45:00',
#         'depDate': '2025-01-07',
#         'arrTime': '12:45:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT4M'},
#        {'name': 'Halmstad Centralstation',
#         'id': 'A=1@O=Halmstad Centralstation@X=12864840@Y=56669275@U=1@L=740000080@',
#         'extId': '740000080',
#         'routeIdx': 5,
#         'lon': 12.86484,
#         'lat': 56.669275,
#         'depTime': '13:13:00',
#         'depDate': '2025-01-07',
#         'arrTime': '13:03:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Laholm station',
#         'id': 'A=1@O=Laholm station@X=12999606@Y=56501905@U=1@L=740000058@',
#         'extId': '740000058',
#         'routeIdx': 6,
#         'lon': 12.999606,
#         'lat': 56.501905,
#         'depTime': '13:25:00',
#         'depDate': '2025-01-07',
#         'arrTime': '13:25:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Båstad station',
#         'id': 'A=1@O=Båstad station@X=12906991@Y=56431834@U=1@L=740001603@',
#         'extId': '740001603',
#         'routeIdx': 7,
#         'lon': 12.906991,
#         'lat': 56.431834,
#         'depTime': '13:32:00',
#         'depDate': '2025-01-07',
#         'arrTime': '13:32:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT4M'},
#        {'name': 'Ängelholm station',
#         'id': 'A=1@O=Ängelholm station@X=12854197@Y=56245200@U=1@L=740000064@',
#         'extId': '740000064',
#         'routeIdx': 8,
#         'lon': 12.854197,
#         'lat': 56.2452,
#         'depTime': '13:43:00',
#         'depDate': '2025-01-07',
#         'arrTime': '13:43:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Helsingborg Centralstation',
#         'id': 'A=1@O=Helsingborg Centralstation@X=12694261@Y=56044408@U=1@L=740000044@',
#         'extId': '740000044',
#         'routeIdx': 9,
#         'lon': 12.694261,
#         'lat': 56.044408,
#         'depTime': '14:07:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:04:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Landskrona station',
#         'id': 'A=1@O=Landskrona station@X=12857406@Y=55878898@U=1@L=740001554@',
#         'extId': '740001554',
#         'routeIdx': 10,
#         'lon': 12.857406,
#         'lat': 55.878898,
#         'depTime': '14:19:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:19:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 11,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'depTime': '14:38:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:36:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö Centralstation',
#         'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#         'extId': '740000003',
#         'routeIdx': 12,
#         'lon': 13.00091,
#         'lat': 55.609456,
#         'arrTime': '14:48:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT15M'}]},
#      'JourneyDetail': {'ref': '1|135397|5|1|7012025',
#       'dayOfOperation': '2025-01-07'},
#      'id': '0',
#      'idx': 0,
#      'name': 'Regional Tåg 1087',
#      'number': '1087',
#      'category': 'JRE',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Köpenhamn Österport (Danmark)',
#      'directionFlag': '1',
#      'duration': 'PT3H8M'}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'hintCode': 0},
#   'idx': 0,
#   'tripId': 'C-0',
#   'ctxRecon': '¶HKI¶T$A=1@O=Göteborg Centralstation@L=740000002@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501071140$202501071448$JRE 1087$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT3H8M',
#   'rtDuration': 'PT3H8M',
#   'checksum': '8d996d35_3'},
#  {'Origin': {'name': 'Göteborg Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#    'extId': '740000002',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'time': '12:37:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'time': '16:39:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2024-12-11',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '17. jan t o m 13. apr 2025 fre, sön; och 7., 11. jan',
#     'sDaysB': '142450D1050A142850A142850A1428500000000000000000'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Göteborg Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'time': '12:37:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'Destination': {'name': 'Göteborg Nils Ericsonterminal',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Nils Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#       'extId': '740020483',
#       'lon': 11.971852,
#       'lat': 57.710271,
#       'time': '12:40:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT5M'},
#      'GisRef': {'ref': 'G|1|G@F|A=1@O=Göteborg Centralstation@L=740000002@a=128@|A=1@O=Göteborg Nils Ericsonterminal@L=740020483@a=128@|7012025|123700|124000|bf|ft@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§bt@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§tt@0@5000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§||||'},
#      'GisRoute': {'dist': 187, 'durS': 'PT3M', 'dirGeo': 0},
#      'Product': [{'icon': {'res': 'prod_walk'},
#        'name': 'Promenad',
#        'internalName': 'Promenad'}],
#      'id': '0',
#      'idx': 0,
#      'name': 'Promenad',
#      'type': 'WALK',
#      'duration': 'PT3M',
#      'dist': 187},
#     {'Origin': {'name': 'Göteborg Nils Ericsonterminal',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Nils Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#       'extId': '740020483',
#       'lon': 11.971852,
#       'lat': 57.710271,
#       'routeIdx': 2,
#       'prognosisType': 'PROGNOSED',
#       'time': '12:40:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT5M'},
#      'Destination': {'name': 'Malmö C Norra Vallgatan',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö C Norra Vallgatan@X=13000083@Y=55607918@U=1@L=740072050@',
#       'extId': '740072050',
#       'lon': 13.000083,
#       'lat': 55.607918,
#       'routeIdx': 6,
#       'prognosisType': 'PROGNOSED',
#       'time': '16:35:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT20M'},
#      'Notes': {'Note': [{'value': 'Obligatorisk platsbokning',
#         'key': 'AF',
#         'type': 'A',
#         'routeIdxFrom': 2,
#         'routeIdxTo': 6,
#         'txtN': 'Obligatorisk platsbokning'},
#        {'value': 'Internetuppkoppling',
#         'key': 'AV',
#         'type': 'A',
#         'routeIdxFrom': 2,
#         'routeIdxTo': 6,
#         'txtN': 'Internetuppkoppling'},
#        {'value': 'EU förordning 181/2011',
#         'key': 'EB',
#         'type': 'A',
#         'routeIdxFrom': 2,
#         'routeIdxTo': 6,
#         'txtN': 'EU förordning 181/2011'}]},
#      'JourneyDetailRef': {'ref': '1|8984|0|1|7012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'Vy Bus4You',
#         'nameS': '327',
#         'nameN': '327',
#         'nameL': 'Vy Bus4You',
#         'id': '327'},
#        'name': 'Expressbuss 600',
#        'internalName': 'Expressbuss 600',
#        'displayNumber': '600',
#        'num': '600',
#        'line': '600',
#        'lineId': '1327060000001',
#        'catOut': 'BXB',
#        'catIn': 'BXB',
#        'catCode': '3',
#        'cls': '8',
#        'catOutS': 'BXB',
#        'catOutL': 'Expressbuss',
#        'operatorCode': '327',
#        'operator': 'Vy Bus4You',
#        'admin': '327___',
#        'routeIdxFrom': 2,
#        'routeIdxTo': 6,
#        'matchId': '600;600;602'}],
#      'Stops': {'Stop': [{'name': 'Göteborg Nils Ericsonterminal',
#         'id': 'A=1@O=Göteborg Nils Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#         'extId': '740020483',
#         'routeIdx': 2,
#         'lon': 11.971852,
#         'lat': 57.710271,
#         'depTime': '12:40:00',
#         'depDate': '2025-01-07',
#         'depDir': 'Malmö C Norra Vallgatan',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Halmstad C Resecentrum',
#         'id': 'A=1@O=Halmstad C Resecentrum@X=12865811@Y=56670273@U=1@L=740043449@',
#         'extId': '740043449',
#         'routeIdx': 3,
#         'lon': 12.865811,
#         'lat': 56.670273,
#         'depTime': '14:20:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:20:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Helsingborg Centralstation',
#         'id': 'A=1@O=Helsingborg Centralstation@X=12694261@Y=56044408@U=1@L=740000044@',
#         'extId': '740000044',
#         'routeIdx': 4,
#         'lon': 12.694261,
#         'lat': 56.044408,
#         'depTime': '15:25:00',
#         'depDate': '2025-01-07',
#         'arrTime': '15:25:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 5,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'depTime': '16:10:00',
#         'depDate': '2025-01-07',
#         'arrTime': '16:10:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö C Norra Vallgatan',
#         'id': 'A=1@O=Malmö C Norra Vallgatan@X=13000083@Y=55607918@U=1@L=740072050@',
#         'extId': '740072050',
#         'routeIdx': 6,
#         'lon': 13.000083,
#         'lat': 55.607918,
#         'arrPrognosisType': 'PROGNOSED',
#         'arrTime': '16:35:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT20M'}]},
#      'JourneyDetail': {'ref': '1|8984|0|1|7012025',
#       'dayOfOperation': '2025-01-07'},
#      'id': '1',
#      'idx': 1,
#      'name': 'Expressbuss 600',
#      'number': '600',
#      'category': 'BXB',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Malmö C Norra Vallgatan',
#      'directionFlag': '1',
#      'duration': 'PT3H55M',
#      'minimumChangeDuration': 'PT4M'},
#     {'Origin': {'name': 'Malmö C Norra Vallgatan',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö C Norra Vallgatan@X=13000083@Y=55607918@U=1@L=740072050@',
#       'extId': '740072050',
#       'lon': 13.000083,
#       'lat': 55.607918,
#       'time': '16:35:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT20M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'time': '16:39:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'GisRef': {'ref': 'G|1|G@F|A=1@O=Malmö C Norra Vallgatan@L=740072050@a=128@|A=1@O=Malmö Centralstation@L=740000003@a=128@|7012025|163500|163900|fb|ft@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§bt@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§tt@0@5000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§||||'},
#      'GisRoute': {'dist': 292, 'durS': 'PT4M', 'dirGeo': 0},
#      'Product': [{'icon': {'res': 'prod_walk'},
#        'name': 'Promenad',
#        'internalName': 'Promenad'}],
#      'id': '2',
#      'idx': 2,
#      'name': 'Promenad',
#      'type': 'WALK',
#      'duration': 'PT4M',
#      'dist': 292}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'economic': True,
#    'convenient': True,
#    'hintCode': 0,
#    'unsharp': True},
#   'idx': 1,
#   'tripId': 'C-1',
#   'ctxRecon': '¶HKI¶G@F$A=1@O=Göteborg Centralstation@L=740000002@a=128@$A=1@O=Göteborg Nils Ericsonterminal@L=740020483@a=128@$202501071237$202501071240$$$1$$$$$$§T$A=1@O=Göteborg Nils Ericsonterminal@L=740020483@a=128@$A=1@O=Malmö C Norra Vallgatan@L=740072050@a=128@$202501071240$202501071635$BXB  600$$1$$$$$$§G@F$A=1@O=Malmö C Norra Vallgatan@L=740072050@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501071635$202501071639$$$1$$$$$$¶GP¶ft@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§bt@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§tt@0@5000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT4H2M',
#   'rtDuration': 'PT4H2M',
#   'checksum': 'f4caaed9_3'},
#  {'Origin': {'name': 'Göteborg Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#    'extId': '740000002',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '12:40:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'routeIdx': 12,
#    'prognosisType': 'PROGNOSED',
#    'time': '15:48:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2024-12-11',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '7. jan t o m 8. jun 2025; utom 12. t o m 21. apr 2025, 26. apr',
#     'sDaysB': 'FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFC00F7FFFFFFFFFF000'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Göteborg Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'routeIdx': 0,
#       'prognosisType': 'PROGNOSED',
#       'time': '12:40:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'routeIdx': 12,
#       'prognosisType': 'PROGNOSED',
#       'time': '15:48:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'Notes': {'Note': [{'value': 'Ej reservering',
#         'key': 'AE',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 12,
#         'txtN': 'Ej reservering'},
#        {'value': 'Rullstolslyft',
#         'key': 'AN',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 12,
#         'txtN': 'Rullstolslyft'},
#        {'value': 'EU förordning 2021/782',
#         'key': 'EJ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 12,
#         'txtN': 'EU förordning 2021/782'}]},
#      'JourneyDetailRef': {'ref': '1|135397|6|1|7012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'Öresundståg',
#         'nameS': '300',
#         'nameN': '300',
#         'nameL': 'Öresundståg',
#         'id': '300'},
#        'name': 'Regional Tåg 1095',
#        'internalName': 'Regional Tåg 1095',
#        'displayNumber': '1095',
#        'num': '1095',
#        'line': '1095',
#        'lineId': '1300080400031',
#        'catOut': 'JRE',
#        'catIn': 'JRE',
#        'catCode': '2',
#        'cls': '4',
#        'catOutS': 'JRE',
#        'catOutL': 'Regional Tåg',
#        'operatorCode': '300',
#        'operator': 'Öresundståg',
#        'admin': '300___',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 12,
#        'matchId': '11159;804;1095'}],
#      'Stops': {'Stop': [{'name': 'Göteborg Centralstation',
#         'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#         'extId': '740000002',
#         'routeIdx': 0,
#         'lon': 11.973479,
#         'lat': 57.708895,
#         'depPrognosisType': 'PROGNOSED',
#         'depTime': '12:40:00',
#         'depDate': '2025-01-07',
#         'depDir': 'Köpenhamn Österport (Danmark)',
#         'minimumChangeDuration': 'PT15M'},
#        {'name': 'Mölndal station',
#         'id': 'A=1@O=Mölndal station@X=12018722@Y=57655958@U=1@L=740000315@',
#         'extId': '740000315',
#         'routeIdx': 1,
#         'lon': 12.018722,
#         'lat': 57.655958,
#         'depTime': '12:48:00',
#         'depDate': '2025-01-07',
#         'arrTime': '12:48:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Kungsbacka station',
#         'id': 'A=1@O=Kungsbacka station@X=12079614@Y=57490556@U=1@L=740000161@',
#         'extId': '740000161',
#         'routeIdx': 2,
#         'lon': 12.079614,
#         'lat': 57.490556,
#         'depTime': '12:59:00',
#         'depDate': '2025-01-07',
#         'arrTime': '12:59:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Varberg station',
#         'id': 'A=1@O=Varberg station@X=12248081@Y=57109378@U=1@L=740000110@',
#         'extId': '740000110',
#         'routeIdx': 3,
#         'lon': 12.248081,
#         'lat': 57.109378,
#         'depTime': '13:29:00',
#         'depDate': '2025-01-07',
#         'arrTime': '13:25:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Falkenberg station',
#         'id': 'A=1@O=Falkenberg station@X=12507555@Y=56919768@U=1@L=740001579@',
#         'extId': '740001579',
#         'routeIdx': 4,
#         'lon': 12.507555,
#         'lat': 56.919768,
#         'depTime': '13:45:00',
#         'depDate': '2025-01-07',
#         'arrTime': '13:45:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT4M'},
#        {'name': 'Halmstad Centralstation',
#         'id': 'A=1@O=Halmstad Centralstation@X=12864840@Y=56669275@U=1@L=740000080@',
#         'extId': '740000080',
#         'routeIdx': 5,
#         'lon': 12.86484,
#         'lat': 56.669275,
#         'depTime': '14:13:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:03:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Laholm station',
#         'id': 'A=1@O=Laholm station@X=12999606@Y=56501905@U=1@L=740000058@',
#         'extId': '740000058',
#         'routeIdx': 6,
#         'lon': 12.999606,
#         'lat': 56.501905,
#         'depTime': '14:25:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:25:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Båstad station',
#         'id': 'A=1@O=Båstad station@X=12906991@Y=56431834@U=1@L=740001603@',
#         'extId': '740001603',
#         'routeIdx': 7,
#         'lon': 12.906991,
#         'lat': 56.431834,
#         'depTime': '14:32:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:32:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT4M'},
#        {'name': 'Ängelholm station',
#         'id': 'A=1@O=Ängelholm station@X=12854197@Y=56245200@U=1@L=740000064@',
#         'extId': '740000064',
#         'routeIdx': 8,
#         'lon': 12.854197,
#         'lat': 56.2452,
#         'depTime': '14:43:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:43:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Helsingborg Centralstation',
#         'id': 'A=1@O=Helsingborg Centralstation@X=12694261@Y=56044408@U=1@L=740000044@',
#         'extId': '740000044',
#         'routeIdx': 9,
#         'lon': 12.694261,
#         'lat': 56.044408,
#         'depTime': '15:07:00',
#         'depDate': '2025-01-07',
#         'arrTime': '15:04:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Landskrona station',
#         'id': 'A=1@O=Landskrona station@X=12857406@Y=55878898@U=1@L=740001554@',
#         'extId': '740001554',
#         'routeIdx': 10,
#         'lon': 12.857406,
#         'lat': 55.878898,
#         'depTime': '15:19:00',
#         'depDate': '2025-01-07',
#         'arrTime': '15:19:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 11,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'depTime': '15:38:00',
#         'depDate': '2025-01-07',
#         'arrTime': '15:36:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö Centralstation',
#         'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#         'extId': '740000003',
#         'routeIdx': 12,
#         'lon': 13.00091,
#         'lat': 55.609456,
#         'arrTime': '15:48:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT15M'}]},
#      'JourneyDetail': {'ref': '1|135397|6|1|7012025',
#       'dayOfOperation': '2025-01-07'},
#      'id': '0',
#      'idx': 0,
#      'name': 'Regional Tåg 1095',
#      'number': '1095',
#      'category': 'JRE',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Köpenhamn Österport (Danmark)',
#      'directionFlag': '1',
#      'duration': 'PT3H8M'}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'hintCode': 0},
#   'idx': 2,
#   'tripId': 'C-2',
#   'ctxRecon': '¶HKI¶T$A=1@O=Göteborg Centralstation@L=740000002@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501071240$202501071548$JRE 1095$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT3H8M',
#   'rtDuration': 'PT3H8M',
#   'checksum': '188ea032_3'},
#  {'Origin': {'name': 'Göteborg Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#    'extId': '740000002',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'time': '13:22:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'time': '17:09:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2024-12-11',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '7. jan',
#     'sDaysB': '040010100000000000000000000000000000000000000000'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Göteborg Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'time': '13:22:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'Destination': {'name': 'Göteborg Nils Ericsonterminal',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Nils Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#       'extId': '740020483',
#       'lon': 11.971852,
#       'lat': 57.710271,
#       'time': '13:25:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT5M'},
#      'GisRef': {'ref': 'G|1|G@F|A=1@O=Göteborg Centralstation@L=740000002@a=128@|A=1@O=Göteborg Nils Ericsonterminal@L=740020483@a=128@|7012025|132200|132500|bf|ft@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§bt@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§tt@0@5000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§||||'},
#      'GisRoute': {'dist': 187, 'durS': 'PT3M', 'dirGeo': 0},
#      'Product': [{'icon': {'res': 'prod_walk'},
#        'name': 'Promenad',
#        'internalName': 'Promenad'}],
#      'id': '0',
#      'idx': 0,
#      'name': 'Promenad',
#      'type': 'WALK',
#      'duration': 'PT3M',
#      'dist': 187},
#     {'Origin': {'name': 'Göteborg Nils Ericsonterminal',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Nils Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#       'extId': '740020483',
#       'lon': 11.971852,
#       'lat': 57.710271,
#       'routeIdx': 3,
#       'prognosisType': 'PROGNOSED',
#       'time': '13:25:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT5M'},
#      'Destination': {'name': 'Malmö C Norra Vallgatan',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö C Norra Vallgatan@X=13000083@Y=55607918@U=1@L=740072050@',
#       'extId': '740072050',
#       'lon': 13.000083,
#       'lat': 55.607918,
#       'routeIdx': 6,
#       'prognosisType': 'PROGNOSED',
#       'time': '17:05:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT20M'},
#      'Notes': {'Note': [{'value': 'Obligatorisk platsbokning',
#         'key': 'AF',
#         'type': 'A',
#         'routeIdxFrom': 3,
#         'routeIdxTo': 6,
#         'txtN': 'Obligatorisk platsbokning'},
#        {'value': 'Internetuppkoppling',
#         'key': 'AV',
#         'type': 'A',
#         'routeIdxFrom': 3,
#         'routeIdxTo': 6,
#         'txtN': 'Internetuppkoppling'},
#        {'value': 'EU förordning 181/2011',
#         'key': 'EB',
#         'type': 'A',
#         'routeIdxFrom': 3,
#         'routeIdxTo': 6,
#         'txtN': 'EU förordning 181/2011'}]},
#      'JourneyDetailRef': {'ref': '1|9396|0|1|7012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'Vy Bus4You',
#         'nameS': '327',
#         'nameN': '327',
#         'nameL': 'Vy Bus4You',
#         'id': '327'},
#        'name': 'Expressbuss 600',
#        'internalName': 'Expressbuss 600',
#        'displayNumber': '600',
#        'num': '600',
#        'line': '600',
#        'lineId': '1327060000001',
#        'catOut': 'BXB',
#        'catIn': 'BXB',
#        'catCode': '3',
#        'cls': '8',
#        'catOutS': 'BXB',
#        'catOutL': 'Expressbuss',
#        'operatorCode': '327',
#        'operator': 'Vy Bus4You',
#        'admin': '327___',
#        'routeIdxFrom': 3,
#        'routeIdxTo': 6,
#        'matchId': '600;600;648'}],
#      'Stops': {'Stop': [{'name': 'Göteborg Nils Ericsonterminal',
#         'id': 'A=1@O=Göteborg Nils Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#         'extId': '740020483',
#         'routeIdx': 3,
#         'lon': 11.971852,
#         'lat': 57.710271,
#         'depTime': '13:25:00',
#         'depDate': '2025-01-07',
#         'depDir': 'Köpenhamn Dybbölsbro busterm (Danmark)',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Halmstad C Resecentrum',
#         'id': 'A=1@O=Halmstad C Resecentrum@X=12865811@Y=56670273@U=1@L=740043449@',
#         'extId': '740043449',
#         'routeIdx': 4,
#         'lon': 12.865811,
#         'lat': 56.670273,
#         'depTime': '15:05:00',
#         'depDate': '2025-01-07',
#         'arrTime': '15:05:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Helsingborg Centralstation',
#         'id': 'A=1@O=Helsingborg Centralstation@X=12694261@Y=56044408@U=1@L=740000044@',
#         'extId': '740000044',
#         'routeIdx': 5,
#         'lon': 12.694261,
#         'lat': 56.044408,
#         'depTime': '16:10:00',
#         'depDate': '2025-01-07',
#         'arrTime': '16:10:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Malmö C Norra Vallgatan',
#         'id': 'A=1@O=Malmö C Norra Vallgatan@X=13000083@Y=55607918@U=1@L=740072050@',
#         'extId': '740072050',
#         'routeIdx': 6,
#         'lon': 13.000083,
#         'lat': 55.607918,
#         'arrTime': '17:05:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT20M'}]},
#      'JourneyDetail': {'ref': '1|9396|0|1|7012025',
#       'dayOfOperation': '2025-01-07'},
#      'id': '1',
#      'idx': 1,
#      'name': 'Expressbuss 600',
#      'number': '600',
#      'category': 'BXB',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Köpenhamn Dybbölsbro busterm (Danmark)',
#      'directionFlag': '1',
#      'duration': 'PT3H40M',
#      'minimumChangeDuration': 'PT4M'},
#     {'Origin': {'name': 'Malmö C Norra Vallgatan',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö C Norra Vallgatan@X=13000083@Y=55607918@U=1@L=740072050@',
#       'extId': '740072050',
#       'lon': 13.000083,
#       'lat': 55.607918,
#       'time': '17:05:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT20M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'time': '17:09:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'GisRef': {'ref': 'G|1|G@F|A=1@O=Malmö C Norra Vallgatan@L=740072050@a=128@|A=1@O=Malmö Centralstation@L=740000003@a=128@|7012025|170500|170900|fb|ft@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§bt@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§tt@0@5000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§||||'},
#      'GisRoute': {'dist': 292, 'durS': 'PT4M', 'dirGeo': 0},
#      'Product': [{'icon': {'res': 'prod_walk'},
#        'name': 'Promenad',
#        'internalName': 'Promenad'}],
#      'id': '2',
#      'idx': 2,
#      'name': 'Promenad',
#      'type': 'WALK',
#      'duration': 'PT4M',
#      'dist': 292}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'economic': True,
#    'convenient': True,
#    'hintCode': 0,
#    'unsharp': True},
#   'idx': 3,
#   'tripId': 'C-3',
#   'ctxRecon': '¶HKI¶G@F$A=1@O=Göteborg Centralstation@L=740000002@a=128@$A=1@O=Göteborg Nils Ericsonterminal@L=740020483@a=128@$202501071322$202501071325$$$1$$$$$$§T$A=1@O=Göteborg Nils Ericsonterminal@L=740020483@a=128@$A=1@O=Malmö C Norra Vallgatan@L=740072050@a=128@$202501071325$202501071705$BXB  600$$1$$$$$$§G@F$A=1@O=Malmö C Norra Vallgatan@L=740072050@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501071705$202501071709$$$1$$$$$$¶GP¶ft@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§bt@0@2000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§tt@0@5000@120@1@100@1@0@0@@@@@false@0@-1@0@-1@-1@$f@$f@$f@$f@$f@$§¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT3H47M',
#   'rtDuration': 'PT3H47M',
#   'checksum': '919b60f5_3'},
#  {'Origin': {'name': 'Göteborg Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#    'extId': '740000002',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '13:24:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'routeIdx': 4,
#    'prognosisType': 'PROGNOSED',
#    'time': '15:57:00',
#    'date': '2025-01-07',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2024-12-11',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '7. jan t o m 8. jun 2025; utom 15. mar, 12. t o m 21. apr 2025, 26. apr, 17., 18. maj',
#     'sDaysB': '00000FFFFFFFFFFFFFFFFFFDFFFFFFC00F7FFFF9FFFFF000'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Göteborg Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'routeIdx': 0,
#       'prognosisType': 'PROGNOSED',
#       'time': '13:24:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'routeIdx': 4,
#       'prognosisType': 'PROGNOSED',
#       'time': '15:57:00',
#       'date': '2025-01-07',
#       'minimumChangeDuration': 'PT15M'},
#      'Notes': {'Note': [{'value': 'SJ3000',
#         'key': 'V3',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'SJ3000'},
#        {'value': 'Mat 1 klass',
#         'key': 'A1',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'Mat 1 klass'},
#        {'value': 'Bistrovagn',
#         'key': 'AD',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'Bistrovagn'},
#        {'value': 'Obligatorisk platsbokning',
#         'key': 'AF',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'Obligatorisk platsbokning'},
#        {'value': 'Rullstolslyft',
#         'key': 'AN',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'Rullstolslyft'},
#        {'value': 'WiFi',
#         'key': 'AW',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'WiFi'},
#        {'value': '2 klass lugn',
#         'key': 'BL',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': '2 klass lugn'},
#        {'value': 'EU förordning 2021/782',
#         'key': 'EJ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'EU förordning 2021/782'},
#        {'value': 'Maträtt',
#         'key': 'SM',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'Maträtt'},
#        {'value': '1 klass med extra komfort',
#         'key': 'SU',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': '1 klass med extra komfort'},
#        {'value': 'Kaffebuffé 1 klass',
#         'key': 'SZ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 4,
#         'txtN': 'Kaffebuffé 1 klass'}]},
#      'JourneyDetailRef': {'ref': '1|146714|0|1|7012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'SJ',
#         'nameS': '74',
#         'nameN': '74',
#         'nameL': 'SJ',
#         'id': '74'},
#        'name': 'Snabbtåg 491',
#        'internalName': 'Snabbtåg 491',
#        'displayNumber': '491',
#        'num': '491',
#        'line': '491',
#        'lineId': '1074049100001',
#        'catOut': 'JST',
#        'catIn': 'JST',
#        'catCode': '1',
#        'cls': '2',
#        'catOutS': 'JST',
#        'catOutL': 'Snabbtåg',
#        'operatorCode': '74',
#        'operator': 'SJ',
#        'admin': '074___',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'matchId': '491;491;7513'}],
#      'Stops': {'Stop': [{'name': 'Göteborg Centralstation',
#         'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#         'extId': '740000002',
#         'routeIdx': 0,
#         'lon': 11.973479,
#         'lat': 57.708895,
#         'depPrognosisType': 'PROGNOSED',
#         'depTime': '13:24:00',
#         'depDate': '2025-01-07',
#         'depDir': 'Malmö Centralstation',
#         'minimumChangeDuration': 'PT15M'},
#        {'name': 'Halmstad Centralstation',
#         'id': 'A=1@O=Halmstad Centralstation@X=12864840@Y=56669275@U=1@L=740000080@',
#         'extId': '740000080',
#         'routeIdx': 1,
#         'lon': 12.86484,
#         'lat': 56.669275,
#         'depTime': '14:35:00',
#         'depDate': '2025-01-07',
#         'arrTime': '14:34:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Helsingborg Centralstation',
#         'id': 'A=1@O=Helsingborg Centralstation@X=12694261@Y=56044408@U=1@L=740000044@',
#         'extId': '740000044',
#         'routeIdx': 2,
#         'lon': 12.694261,
#         'lat': 56.044408,
#         'depTime': '15:15:00',
#         'depDate': '2025-01-07',
#         'arrTime': '15:14:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT9M'},
#        {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#            'key': 'text.realtime.stop.entry.disabled',
#            'type': 'R',
#            'txtN': 'Stannar endast för avstigande'}]},
#         'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 3,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'arrTime': '15:45:00',
#         'arrDate': '2025-01-07',
#         'boarding': False,
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö Centralstation',
#         'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#         'extId': '740000003',
#         'routeIdx': 4,
#         'lon': 13.00091,
#         'lat': 55.609456,
#         'arrPrognosisType': 'PROGNOSED',
#         'arrTime': '15:57:00',
#         'arrDate': '2025-01-07',
#         'minimumChangeDuration': 'PT15M'}]},
#      'JourneyDetail': {'ref': '1|146714|0|1|7012025',
#       'dayOfOperation': '2025-01-07'},
#      'id': '0',
#      'idx': 0,
#      'name': 'Snabbtåg 491',
#      'number': '491',
#      'category': 'JST',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Malmö Centralstation',
#      'directionFlag': '1',
#      'duration': 'PT2H33M'}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'hintCode': 0},
#   'idx': 4,
#   'tripId': 'C-4',
#   'ctxRecon': '¶HKI¶T$A=1@O=Göteborg Centralstation@L=740000002@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501071324$202501071557$JST  491$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT2H33M',
#   'rtDuration': 'PT2H33M',
#   'checksum': '504564f0_3'}]

# %%
result["ResultStatus"], result["TechnicalMessages"], result["planRtTs"], result["scrB"]
# Out:
# ({'timeDiffCritical': False},
#  {'TechnicalMessage': [{'value': '2025-01-07 11:11:13', 'key': 'requestTime'},
#    {'value': 'ttp=16417#16603 plancode0=zzlri planid=1736224604 planid0=1736224604 planid_adr=1479298166 plancode_adr=q0r10 srvv=5.45.SAMTRAFIKEN.15.0.1 (customer/hcusamtrafiken/release/2023.10.0) [2023-10-19] tlibv=TRFVER: rel/pproxy/4.00.0 2022-10-24 18:24:51 +0200 Relay_EnrichmentProxy v1 jno=1',
#     'key': 'backendInfo'}]},
#  '1970-01-01T01:00:00.000+01:00',
#  '3|OB|MTµ14µ42460µ42460µ42648µ42648µ0µ0µ365µ42431µ1µ0µ1122µ0µ0µ-2147483648µ1µ2|PDHµ378355956619a5b7de5fd8151f63f427|RDµ7012025|RTµ111114|USµ1|RSµINIT')

# %%
example_trip = result["Trip"][0]
example_trip.keys()
# Out:
# dict_keys(['Origin', 'Destination', 'ServiceDays', 'LegList', 'calculation', 'TripStatus', 'idx', 'tripId', 'ctxRecon', 'duration', 'rtDuration', 'checksum'])

# %%
example_trip["Origin"]
# Out:
# {'name': 'Göteborg Centralstation',
#  'type': 'ST',
#  'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#  'extId': '740000002',
#  'lon': 11.973479,
#  'lat': 57.708895,
#  'routeIdx': 0,
#  'prognosisType': 'PROGNOSED',
#  'time': '11:40:00',
#  'date': '2025-01-07',
#  'minimumChangeDuration': 'PT15M'}

# %%
example_trip["Destination"]
# Out:
# {'name': 'Malmö Centralstation',
#  'type': 'ST',
#  'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#  'extId': '740000003',
#  'lon': 13.00091,
#  'lat': 55.609456,
#  'routeIdx': 12,
#  'prognosisType': 'PROGNOSED',
#  'time': '14:48:00',
#  'date': '2025-01-07',
#  'minimumChangeDuration': 'PT15M'}

# %%
example_trip["LegList"]["Leg"][0].keys()
# Out:
# dict_keys(['Origin', 'Destination', 'Notes', 'JourneyDetailRef', 'JourneyStatus', 'Product', 'Stops', 'JourneyDetail', 'id', 'idx', 'name', 'number', 'category', 'type', 'reachable', 'waitingState', 'direction', 'directionFlag', 'duration'])

# %%
stops = example_trip["LegList"]["Leg"][0]["Stops"]["Stop"]
stops
# Out:
# [{'name': 'Göteborg Centralstation',
#   'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#   'extId': '740000002',
#   'routeIdx': 0,
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'depPrognosisType': 'PROGNOSED',
#   'depTime': '11:40:00',
#   'depDate': '2025-01-07',
#   'depDir': 'Köpenhamn Österport (Danmark)',
#   'minimumChangeDuration': 'PT15M'},
#  {'name': 'Mölndal station',
#   'id': 'A=1@O=Mölndal station@X=12018722@Y=57655958@U=1@L=740000315@',
#   'extId': '740000315',
#   'routeIdx': 1,
#   'lon': 12.018722,
#   'lat': 57.655958,
#   'depTime': '11:48:00',
#   'depDate': '2025-01-07',
#   'arrTime': '11:48:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT9M'},
#  {'name': 'Kungsbacka station',
#   'id': 'A=1@O=Kungsbacka station@X=12079614@Y=57490556@U=1@L=740000161@',
#   'extId': '740000161',
#   'routeIdx': 2,
#   'lon': 12.079614,
#   'lat': 57.490556,
#   'depTime': '11:59:00',
#   'depDate': '2025-01-07',
#   'arrTime': '11:59:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT5M'},
#  {'name': 'Varberg station',
#   'id': 'A=1@O=Varberg station@X=12248081@Y=57109378@U=1@L=740000110@',
#   'extId': '740000110',
#   'routeIdx': 3,
#   'lon': 12.248081,
#   'lat': 57.109378,
#   'depTime': '12:29:00',
#   'depDate': '2025-01-07',
#   'arrTime': '12:25:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT5M'},
#  {'name': 'Falkenberg station',
#   'id': 'A=1@O=Falkenberg station@X=12507555@Y=56919768@U=1@L=740001579@',
#   'extId': '740001579',
#   'routeIdx': 4,
#   'lon': 12.507555,
#   'lat': 56.919768,
#   'depTime': '12:45:00',
#   'depDate': '2025-01-07',
#   'arrTime': '12:45:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT4M'},
#  {'name': 'Halmstad Centralstation',
#   'id': 'A=1@O=Halmstad Centralstation@X=12864840@Y=56669275@U=1@L=740000080@',
#   'extId': '740000080',
#   'routeIdx': 5,
#   'lon': 12.86484,
#   'lat': 56.669275,
#   'depTime': '13:13:00',
#   'depDate': '2025-01-07',
#   'arrTime': '13:03:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Laholm station',
#   'id': 'A=1@O=Laholm station@X=12999606@Y=56501905@U=1@L=740000058@',
#   'extId': '740000058',
#   'routeIdx': 6,
#   'lon': 12.999606,
#   'lat': 56.501905,
#   'depTime': '13:25:00',
#   'depDate': '2025-01-07',
#   'arrTime': '13:25:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT9M'},
#  {'name': 'Båstad station',
#   'id': 'A=1@O=Båstad station@X=12906991@Y=56431834@U=1@L=740001603@',
#   'extId': '740001603',
#   'routeIdx': 7,
#   'lon': 12.906991,
#   'lat': 56.431834,
#   'depTime': '13:32:00',
#   'depDate': '2025-01-07',
#   'arrTime': '13:32:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT4M'},
#  {'name': 'Ängelholm station',
#   'id': 'A=1@O=Ängelholm station@X=12854197@Y=56245200@U=1@L=740000064@',
#   'extId': '740000064',
#   'routeIdx': 8,
#   'lon': 12.854197,
#   'lat': 56.2452,
#   'depTime': '13:43:00',
#   'depDate': '2025-01-07',
#   'arrTime': '13:43:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Helsingborg Centralstation',
#   'id': 'A=1@O=Helsingborg Centralstation@X=12694261@Y=56044408@U=1@L=740000044@',
#   'extId': '740000044',
#   'routeIdx': 9,
#   'lon': 12.694261,
#   'lat': 56.044408,
#   'depTime': '14:07:00',
#   'depDate': '2025-01-07',
#   'arrTime': '14:04:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT9M'},
#  {'name': 'Landskrona station',
#   'id': 'A=1@O=Landskrona station@X=12857406@Y=55878898@U=1@L=740001554@',
#   'extId': '740001554',
#   'routeIdx': 10,
#   'lon': 12.857406,
#   'lat': 55.878898,
#   'depTime': '14:19:00',
#   'depDate': '2025-01-07',
#   'arrTime': '14:19:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT9M'},
#  {'name': 'Lund Centralstation',
#   'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#   'extId': '740000120',
#   'routeIdx': 11,
#   'lon': 13.186897,
#   'lat': 55.708094,
#   'depTime': '14:38:00',
#   'depDate': '2025-01-07',
#   'arrTime': '14:36:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Malmö Centralstation',
#   'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#   'extId': '740000003',
#   'routeIdx': 12,
#   'lon': 13.00091,
#   'lat': 55.609456,
#   'arrTime': '14:48:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT15M'}]

# %%
for stop in stops:
    print(f"{stop['name']} {stop.get('depTime')}")
# Out:
# Göteborg Centralstation 11:40:00
# Mölndal station 11:48:00
# Kungsbacka station 11:59:00
# Varberg station 12:29:00
# Falkenberg station 12:45:00
# Halmstad Centralstation 13:13:00
# Laholm station 13:25:00
# Båstad station 13:32:00
# Ängelholm station 13:43:00
# Helsingborg Centralstation 14:07:00
# Landskrona station 14:19:00
# Lund Centralstation 14:38:00
# Malmö Centralstation None

# %% [markdown]
# # Stop lookup

# %%
location = "göteborg"
url = f"https://api.resrobot.se/v2.1/location.name?input={location}&format=json&accessId={API_KEY}"
response = requests.get(url)
result = response.json()
result.keys()
# Out:
# dict_keys(['stopLocationOrCoordLocation', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'requestId'])

# %%
stop_locations = result["stopLocationOrCoordLocation"]
len(stop_locations)
# Out:
# 10

# %%
stop_locations[0]
# Out:
# {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '2'},
#    {'icon': {'res': 'prod_gen'}, 'cls': '4'},
#    {'icon': {'res': 'prod_gen'}, 'cls': '8'},
#    {'icon': {'res': 'prod_gen'}, 'cls': '16'},
#    {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#    {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#    {'icon': {'res': 'prod_gen'}, 'cls': '256'}],
#   'timezoneOffset': 60,
#   'id': 'A=1@O=GÖTEBORG@X=11973479@Y=57708895@U=1@L=740098001@B=1@p=1736224604@',
#   'extId': '740098001',
#   'name': 'GÖTEBORG',
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'weight': 15424,
#   'products': 222,
#   'meta': True,
#   'minimumChangeDuration': 'PT26M'}}

# %%
location_id = 740098001
url = f"https://api.resrobot.se/v2.1/departureBoard?id={location_id}&format=json&accessId={API_KEY}"

response = requests.get(url)
response.json()["Departure"]
# Out:
# [{'JourneyDetailRef': {'ref': '1|37798|9|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 21',
#    'internalName': 'Länstrafik - Buss 21',
#    'displayNumber': '21',
#    'num': '21',
#    'line': '21',
#    'lineId': '1279502100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '21;5021;78'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 21',
#     'internalName': 'Länstrafik - Buss 21',
#     'displayNumber': '21',
#     'num': '21',
#     'line': '21',
#     'lineId': '1279502100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 11,
#     'routeIdxTo': 23,
#     'matchId': '21;5021;78'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 11,
#      'routeIdxTo': 23,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 21',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:43:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Eketrägatan',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|37798|9|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 21',
#    'internalName': 'Länstrafik - Buss 21',
#    'displayNumber': '21',
#    'num': '21',
#    'line': '21',
#    'lineId': '1279502100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '21;5021;78'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 21',
#     'internalName': 'Länstrafik - Buss 21',
#     'displayNumber': '21',
#     'num': '21',
#     'line': '21',
#     'lineId': '1279502100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 12,
#     'routeIdxTo': 23,
#     'matchId': '21;5021;78'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 12,
#      'routeIdxTo': 23,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 21',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '11:43:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Eketrägatan',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|115041|15|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 2',
#    'internalName': 'Länstrafik - Spårväg 2',
#    'displayNumber': '2',
#    'num': '2',
#    'line': '2',
#    'lineId': '1279500200001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '2;5002;4907'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 2',
#     'internalName': 'Länstrafik - Spårväg 2',
#     'displayNumber': '2',
#     'num': '2',
#     'line': '2',
#     'lineId': '1279500200001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 13,
#     'routeIdxTo': 26,
#     'matchId': '2;5002;4907'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 13,
#      'routeIdxTo': 26,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 2',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:43:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Mölndals Innerstad',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|37716|3|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 21',
#    'internalName': 'Länstrafik - Buss 21',
#    'displayNumber': '21',
#    'num': '21',
#    'line': '21',
#    'lineId': '1279502100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '21;5021;75'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 21',
#     'internalName': 'Länstrafik - Buss 21',
#     'displayNumber': '21',
#     'num': '21',
#     'line': '21',
#     'lineId': '1279502100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 12,
#     'routeIdxTo': 23,
#     'matchId': '21;5021;75'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 12,
#      'routeIdxTo': 23,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 21',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:44:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Merkuriusgatan (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|101260|11|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss X1',
#    'internalName': 'Länstrafik - Buss X1',
#    'displayNumber': 'X1',
#    'num': 'X1',
#    'line': 'X1',
#    'lineId': '1279521200001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'X1;5212;83'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss X1',
#     'internalName': 'Länstrafik - Buss X1',
#     'displayNumber': 'X1',
#     'num': 'X1',
#     'line': 'X1',
#     'lineId': '1279521200001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 2,
#     'routeIdxTo': 20,
#     'matchId': 'X1;5212;83'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 2,
#      'routeIdxTo': 20,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss X1',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '11:44:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Hornkamsgatan (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|500|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss X4',
#    'internalName': 'Länstrafik - Buss X4',
#    'displayNumber': 'X4',
#    'num': 'X4',
#    'line': 'X4',
#    'lineId': '1279520500001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'X4;5205;118'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss X4',
#     'internalName': 'Länstrafik - Buss X4',
#     'displayNumber': 'X4',
#     'num': 'X4',
#     'line': 'X4',
#     'lineId': '1279520500001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 19,
#     'routeIdxTo': 27,
#     'matchId': 'X4;5205;118'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 19,
#      'routeIdxTo': 27,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss X4',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '11:45:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Kungälv resecentrum',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|19342|13|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 7',
#    'internalName': 'Länstrafik - Spårväg 7',
#    'displayNumber': '7',
#    'num': '7',
#    'line': '7',
#    'lineId': '1279500700001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '7;5007;4889'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 7',
#     'internalName': 'Länstrafik - Spårväg 7',
#     'displayNumber': '7',
#     'num': '7',
#     'line': '7',
#     'lineId': '1279500700001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 20,
#     'routeIdxTo': 34,
#     'matchId': '7;5007;4889'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 20,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 7',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:45:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Bergsjön Komettorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|30362|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 4',
#    'internalName': 'Länstrafik - Spårväg 4',
#    'displayNumber': '4',
#    'num': '4',
#    'line': '4',
#    'lineId': '1279500400001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '4;5004;4514'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 4',
#     'internalName': 'Länstrafik - Spårväg 4',
#     'displayNumber': '4',
#     'num': '4',
#     'line': '4',
#     'lineId': '1279500400001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 5,
#     'routeIdxTo': 20,
#     'matchId': '4;5004;4514'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 5,
#      'routeIdxTo': 20,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 4',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:45:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Mölndals Innerstad',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|147120|13|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Flygbussarna',
#     'nameS': '277',
#     'nameN': '277',
#     'nameL': 'Flygbussarna',
#     'id': '277'},
#    'name': 'Flygtransfer - Buss .',
#    'internalName': 'Flygtransfer - Buss .',
#    'displayNumber': '.',
#    'num': '.',
#    'line': '.',
#    'lineId': '1277020200001',
#    'catOut': 'BAX',
#    'catIn': 'BAX',
#    'catCode': '3',
#    'cls': '8',
#    'catOutS': 'BAX',
#    'catOutL': 'Flygtransfer - Buss',
#    'operatorCode': '277',
#    'operator': 'Flygbussarna',
#    'admin': '277___',
#    'matchId': '202;202;44759'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Flygbussarna',
#      'nameS': '277',
#      'nameN': '277',
#      'nameL': 'Flygbussarna',
#      'id': '277'},
#     'name': 'Flygtransfer - Buss .',
#     'internalName': 'Flygtransfer - Buss .',
#     'displayNumber': '.',
#     'num': '.',
#     'line': '.',
#     'lineId': '1277020200001',
#     'catOut': 'BAX',
#     'catIn': 'BAX',
#     'catCode': '3',
#     'cls': '8',
#     'catOutS': 'BAX',
#     'catOutL': 'Flygtransfer - Buss',
#     'operatorCode': '277',
#     'operator': 'Flygbussarna',
#     'admin': '277___',
#     'routeIdxFrom': 0,
#     'routeIdxTo': 5,
#     'matchId': '202;202;44759'}],
#   'Notes': {'Note': [{'value': 'Internetuppkoppling',
#      'key': 'AV',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 5,
#      'txtN': 'Internetuppkoppling'},
#     {'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 5,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Flygtransfer - Buss .',
#   'type': 'ST',
#   'stop': 'Göteborg Nils Ericsonterminal',
#   'stopid': 'A=1@O=Göteborg Nils Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#   'stopExtId': '740020483',
#   'lon': 11.971852,
#   'lat': 57.710271,
#   'time': '11:45:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Landvetter Airport (Härryda kn)',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|147616|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Tåg 3047',
#    'internalName': 'Länstrafik - Tåg 3047',
#    'displayNumber': '3047',
#    'num': '3047',
#    'line': '3047',
#    'lineId': '1279000000530',
#    'catOut': 'JLT',
#    'catIn': 'JLT',
#    'catCode': '4',
#    'cls': '16',
#    'catOutS': 'JLT',
#    'catOutL': 'Länstrafik - Tåg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'T25C001 G-KB LT;T25C001 G-KB LT;3047'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Tåg 3047',
#     'internalName': 'Länstrafik - Tåg 3047',
#     'displayNumber': '3047',
#     'num': '3047',
#     'line': '3047',
#     'lineId': '1279000000530',
#     'catOut': 'JLT',
#     'catIn': 'JLT',
#     'catCode': '4',
#     'cls': '16',
#     'catOutS': 'JLT',
#     'catOutL': 'Länstrafik - Tåg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 0,
#     'routeIdxTo': 7,
#     'matchId': 'T25C001 G-KB LT;T25C001 G-KB LT;3047'}],
#   'Notes': {'Note': [{'value': 'Endast 2 klass',
#      'key': 'AA',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 7,
#      'txtN': 'Endast 2 klass'},
#     {'value': 'Ej reservering',
#      'key': 'AE',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 7,
#      'txtN': 'Ej reservering'},
#     {'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 7,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Tåg 3047',
#   'type': 'ST',
#   'stop': 'Göteborg Centralstation',
#   'stopid': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#   'stopExtId': '740000002',
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'time': '11:45:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Kungsbacka station',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|29969|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 4',
#    'internalName': 'Länstrafik - Spårväg 4',
#    'displayNumber': '4',
#    'num': '4',
#    'line': '4',
#    'lineId': '1279500400001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '4;5004;4447'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 4',
#     'internalName': 'Länstrafik - Spårväg 4',
#     'displayNumber': '4',
#     'num': '4',
#     'line': '4',
#     'lineId': '1279500400001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 15,
#     'routeIdxTo': 20,
#     'matchId': '4;5004;4447'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 15,
#      'routeIdxTo': 20,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 4',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:46:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Angered centrum (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|69591|15|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 17',
#    'internalName': 'Länstrafik - Buss 17',
#    'displayNumber': '17',
#    'num': '17',
#    'line': '17',
#    'lineId': '1279501700001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '17;5017;101'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 17',
#     'internalName': 'Länstrafik - Buss 17',
#     'displayNumber': '17',
#     'num': '17',
#     'line': '17',
#     'lineId': '1279501700001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 13,
#     'routeIdxTo': 27,
#     'matchId': '17;5017;101'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 13,
#      'routeIdxTo': 27,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 17',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '11:46:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Östra sjukhuset',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|154428|6|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss RÖD',
#    'internalName': 'Länstrafik - Buss RÖD',
#    'displayNumber': 'RÖD',
#    'num': 'RÖD',
#    'line': 'RÖD',
#    'lineId': '1279620100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'RÖD;6201;101'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss RÖD',
#     'internalName': 'Länstrafik - Buss RÖD',
#     'displayNumber': 'RÖD',
#     'num': 'RÖD',
#     'line': 'RÖD',
#     'lineId': '1279620100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 12,
#     'routeIdxTo': 26,
#     'matchId': 'RÖD;6201;101'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 12,
#      'routeIdxTo': 26,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss RÖD',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:46:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Lilla Varholmen (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|156852|13|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 1',
#    'internalName': 'Länstrafik - Spårväg 1',
#    'displayNumber': '1',
#    'num': '1',
#    'line': '1',
#    'lineId': '1279500100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '1;5001;4901'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 1',
#     'internalName': 'Länstrafik - Spårväg 1',
#     'displayNumber': '1',
#     'num': '1',
#     'line': '1',
#     'lineId': '1279500100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 17,
#     'routeIdxTo': 28,
#     'matchId': '1;5001;4901'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 17,
#      'routeIdxTo': 28,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 1',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:46:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Östra sjukhuset',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|159229|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 6',
#    'internalName': 'Länstrafik - Spårväg 6',
#    'displayNumber': '6',
#    'num': '6',
#    'line': '6',
#    'lineId': '1279500600001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '6;5006;93'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 6',
#     'internalName': 'Länstrafik - Spårväg 6',
#     'displayNumber': '6',
#     'num': '6',
#     'line': '6',
#     'lineId': '1279500600001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 15,
#     'routeIdxTo': 45,
#     'matchId': '6;5006;93'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 15,
#      'routeIdxTo': 45,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 6',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '11:46:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Kortedala Aprilgatan (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|310|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss X4',
#    'internalName': 'Länstrafik - Buss X4',
#    'displayNumber': 'X4',
#    'num': 'X4',
#    'line': 'X4',
#    'lineId': '1279520500001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'X4;5205;119'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss X4',
#     'internalName': 'Länstrafik - Buss X4',
#     'displayNumber': 'X4',
#     'num': 'X4',
#     'line': 'X4',
#     'lineId': '1279520500001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 8,
#     'routeIdxTo': 21,
#     'matchId': 'X4;5205;119'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 8,
#      'routeIdxTo': 21,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss X4',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '11:47:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Mölnlycke station (Härryda kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|19609|17|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 7',
#    'internalName': 'Länstrafik - Spårväg 7',
#    'displayNumber': '7',
#    'num': '7',
#    'line': '7',
#    'lineId': '1279500700001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '7;5007;4940'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 7',
#     'internalName': 'Länstrafik - Spårväg 7',
#     'displayNumber': '7',
#     'num': '7',
#     'line': '7',
#     'lineId': '1279500700001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 14,
#     'routeIdxTo': 34,
#     'matchId': '7;5007;4940'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 14,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 7',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:48:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Tynnered Opaltorget (Göteborg kn)',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|57367|4|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 60',
#    'internalName': 'Länstrafik - Buss 60',
#    'displayNumber': '60',
#    'num': '60',
#    'line': '60',
#    'lineId': '1279506000001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '60;5060;87'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 60',
#     'internalName': 'Länstrafik - Buss 60',
#     'displayNumber': '60',
#     'num': '60',
#     'line': '60',
#     'lineId': '1279506000001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 11,
#     'routeIdxTo': 22,
#     'matchId': '60;5060;87'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 11,
#      'routeIdxTo': 22,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 60',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:48:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Sörgårdsskolan (Mölndal kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|69591|15|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 17',
#    'internalName': 'Länstrafik - Buss 17',
#    'displayNumber': '17',
#    'num': '17',
#    'line': '17',
#    'lineId': '1279501700001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '17;5017;101'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 17',
#     'internalName': 'Länstrafik - Buss 17',
#     'displayNumber': '17',
#     'num': '17',
#     'line': '17',
#     'lineId': '1279501700001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 14,
#     'routeIdxTo': 27,
#     'matchId': '17;5017;101'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 14,
#      'routeIdxTo': 27,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 17',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:48:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Östra sjukhuset',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|105847|18|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 9',
#    'internalName': 'Länstrafik - Spårväg 9',
#    'displayNumber': '9',
#    'num': '9',
#    'line': '9',
#    'lineId': '1279500900001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '9;5009;4956'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 9',
#     'internalName': 'Länstrafik - Spårväg 9',
#     'displayNumber': '9',
#     'num': '9',
#     'line': '9',
#     'lineId': '1279500900001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 5,
#     'routeIdxTo': 20,
#     'matchId': '9;5009;4956'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 5,
#      'routeIdxTo': 20,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 9',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:48:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Kungssten',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|115247|4|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 2',
#    'internalName': 'Länstrafik - Spårväg 2',
#    'displayNumber': '2',
#    'num': '2',
#    'line': '2',
#    'lineId': '1279500200001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '2;5002;4948'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 2',
#     'internalName': 'Länstrafik - Spårväg 2',
#     'displayNumber': '2',
#     'num': '2',
#     'line': '2',
#     'lineId': '1279500200001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 13,
#     'routeIdxTo': 26,
#     'matchId': '2;5002;4948'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 13,
#      'routeIdxTo': 26,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 2',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:48:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Axel Dahlströms torg',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|187791|1|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss SVART',
#    'internalName': 'Länstrafik - Buss SVART',
#    'displayNumber': 'SVART',
#    'num': 'SVART',
#    'line': 'SVART',
#    'lineId': '1279521100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'SVART;5211;90'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss SVART',
#     'internalName': 'Länstrafik - Buss SVART',
#     'displayNumber': 'SVART',
#     'num': 'SVART',
#     'line': 'SVART',
#     'lineId': '1279521100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 10,
#     'routeIdxTo': 29,
#     'matchId': 'SVART;5211;90'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 10,
#      'routeIdxTo': 29,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss SVART',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:48:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Amhult Resecentrum (Göteborg kn)',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|187791|1|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss SVART',
#    'internalName': 'Länstrafik - Buss SVART',
#    'displayNumber': 'SVART',
#    'num': 'SVART',
#    'line': 'SVART',
#    'lineId': '1279521100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'SVART;5211;90'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss SVART',
#     'internalName': 'Länstrafik - Buss SVART',
#     'displayNumber': 'SVART',
#     'num': 'SVART',
#     'line': 'SVART',
#     'lineId': '1279521100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 11,
#     'routeIdxTo': 29,
#     'matchId': 'SVART;5211;90'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 11,
#      'routeIdxTo': 29,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss SVART',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '11:48:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Amhult Resecentrum (Göteborg kn)',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|22860|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 16',
#    'internalName': 'Länstrafik - Buss 16',
#    'displayNumber': '16',
#    'num': '16',
#    'line': '16',
#    'lineId': '1279501600001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '16;5016;101'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 16',
#     'internalName': 'Länstrafik - Buss 16',
#     'displayNumber': '16',
#     'num': '16',
#     'line': '16',
#     'lineId': '1279501600001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 9,
#     'routeIdxTo': 21,
#     'matchId': '16;5016;101'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 9,
#      'routeIdxTo': 21,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 16',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '11:49:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Fyrktorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|71894|2|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 3',
#    'internalName': 'Länstrafik - Spårväg 3',
#    'displayNumber': '3',
#    'num': '3',
#    'line': '3',
#    'lineId': '1279500300001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '3;5003;4899'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 3',
#     'internalName': 'Länstrafik - Spårväg 3',
#     'displayNumber': '3',
#     'num': '3',
#     'line': '3',
#     'lineId': '1279500300001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 20,
#     'routeIdxTo': 29,
#     'matchId': '3;5003;4899'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 20,
#      'routeIdxTo': 29,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 3',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '11:49:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Virginsgatan (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|101318|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss X1',
#    'internalName': 'Länstrafik - Buss X1',
#    'displayNumber': 'X1',
#    'num': 'X1',
#    'line': 'X1',
#    'lineId': '1279521200001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'X1;5212;78'},
# ...
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 20,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;5013'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 20,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '12:41:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Bergsjön Komettorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|320|0|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss X4',
#    'internalName': 'Länstrafik - Buss X4',
#    'displayNumber': 'X4',
#    'num': 'X4',
#    'line': 'X4',
#    'lineId': '1279520500001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': 'X4;5205;135'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss X4',
#     'internalName': 'Länstrafik - Buss X4',
#     'displayNumber': 'X4',
#     'num': 'X4',
#     'line': 'X4',
#     'lineId': '1279520500001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 8,
#     'routeIdxTo': 21,
#     'matchId': 'X4;5205;135'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 8,
#      'routeIdxTo': 21,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss X4',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '12:42:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Mölnlycke station (Härryda kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|37716|9|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 21',
#    'internalName': 'Länstrafik - Buss 21',
#    'displayNumber': '21',
#    'num': '21',
#    'line': '21',
#    'lineId': '1279502100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '21;5021;87'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 21',
#     'internalName': 'Länstrafik - Buss 21',
#     'displayNumber': '21',
#     'num': '21',
#     'line': '21',
#     'lineId': '1279502100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 11,
#     'routeIdxTo': 23,
#     'matchId': '21;5021;87'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 11,
#      'routeIdxTo': 23,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 21',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '12:42:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Merkuriusgatan (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|57403|2|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 60',
#    'internalName': 'Länstrafik - Buss 60',
#    'displayNumber': '60',
#    'num': '60',
#    'line': '60',
#    'lineId': '1279506000001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '60;5060;98'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 60',
#     'internalName': 'Länstrafik - Buss 60',
#     'displayNumber': '60',
#     'num': '60',
#     'line': '60',
#     'lineId': '1279506000001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 11,
#     'routeIdxTo': 22,
#     'matchId': '60;5060;98'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 11,
#      'routeIdxTo': 22,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 60',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '12:42:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Redbergsplatsen',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|168013|24|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;5064'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 14,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;5064'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 14,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '12:42:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Saltholmens Brygga',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|182736|3|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 100',
#    'internalName': 'Länstrafik - Buss 100',
#    'displayNumber': '100',
#    'num': '100',
#    'line': '100',
#    'lineId': '1279210000001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '100;2100;73'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 100',
#     'internalName': 'Länstrafik - Buss 100',
#     'displayNumber': '100',
#     'num': '100',
#     'line': '100',
#     'lineId': '1279210000001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 0,
#     'routeIdxTo': 3,
#     'matchId': '100;2100;73'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 3,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 100',
#   'type': 'ST',
#   'stop': 'Göteborg Åkareplatsen',
#   'stopid': 'A=1@O=Göteborg Åkareplatsen@X=11975942@Y=57708329@U=1@L=740020490@',
#   'stopExtId': '740020490',
#   'lon': 11.975942,
#   'lat': 57.708329,
#   'time': '12:42:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Borås Centralstation',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|37798|15|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 21',
#    'internalName': 'Länstrafik - Buss 21',
#    'displayNumber': '21',
#    'num': '21',
#    'line': '21',
#    'lineId': '1279502100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '21;5021;90'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 21',
#     'internalName': 'Länstrafik - Buss 21',
#     'displayNumber': '21',
#     'num': '21',
#     'line': '21',
#     'lineId': '1279502100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 11,
#     'routeIdxTo': 23,
#     'matchId': '21;5021;90'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 11,
#      'routeIdxTo': 23,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 21',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '12:43:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Eketrägatan',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|37798|15|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Buss 21',
#    'internalName': 'Länstrafik - Buss 21',
#    'displayNumber': '21',
#    'num': '21',
#    'line': '21',
#    'lineId': '1279502100001',
#    'catOut': 'BLT',
#    'catIn': 'BLT',
#    'catCode': '7',
#    'cls': '128',
#    'catOutS': 'BLT',
#    'catOutL': 'Länstrafik - Buss',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '21;5021;90'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Buss 21',
#     'internalName': 'Länstrafik - Buss 21',
#     'displayNumber': '21',
#     'num': '21',
#     'line': '21',
#     'lineId': '1279502100001',
#     'catOut': 'BLT',
#     'catIn': 'BLT',
#     'catCode': '7',
#     'cls': '128',
#     'catOutS': 'BLT',
#     'catOutL': 'Länstrafik - Buss',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 12,
#     'routeIdxTo': 23,
#     'matchId': '21;5021;90'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 12,
#      'routeIdxTo': 23,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Buss 21',
#   'type': 'ST',
#   'stop': 'Göteborg Nordstan',
#   'stopid': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#   'stopExtId': '740015585',
#   'lon': 11.970791,
#   'lat': 57.709246,
#   'time': '12:43:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Eketrägatan',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|115041|21|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 2',
#    'internalName': 'Länstrafik - Spårväg 2',
#    'displayNumber': '2',
#    'num': '2',
#    'line': '2',
#    'lineId': '1279500200001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '2;5002;5039'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 2',
#     'internalName': 'Länstrafik - Spårväg 2',
#     'displayNumber': '2',
#     'num': '2',
#     'line': '2',
#     'lineId': '1279500200001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 13,
#     'routeIdxTo': 26,
#     'matchId': '2;5002;5039'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 13,
#      'routeIdxTo': 26,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 2',
#   'type': 'ST',
#   'stop': 'Göteborg Centralst Drottningt',
#   'stopid': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@',
#   'stopExtId': '740030117',
#   'lon': 11.97374,
#   'lat': 57.707898,
#   'time': '12:43:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Mölndals Innerstad',
#   'directionFlag': '1'}]

# %%
import pandas as pd

pd.DataFrame(response.json()["Departure"])
# Out:
#                      JourneyDetailRef JourneyStatus  \
# 0      {'ref': '1|37798|9|1|7012025'}             P
# 1      {'ref': '1|37798|9|1|7012025'}             P
# 2    {'ref': '1|115041|15|1|7012025'}             P
# 3      {'ref': '1|37716|3|1|7012025'}             P
# 4    {'ref': '1|101260|11|1|7012025'}             P
# ..                                ...           ...
# 245  {'ref': '1|168013|24|1|7012025'}             P
# 246   {'ref': '1|182736|3|1|7012025'}             P
# 247   {'ref': '1|37798|15|1|7012025'}             P
# 248   {'ref': '1|37798|15|1|7012025'}             P
# 249  {'ref': '1|115041|21|1|7012025'}             P
#
#                                          ProductAtStop  \
# 0    {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 1    {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 2    {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 3    {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 4    {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# ..                                                 ...
# 245  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 246  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 247  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 248  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 249  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
#
#                                                Product  \
# 0    [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1    [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 2    [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 3    [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 4    [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# ..                                                 ...
# 245  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 246  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 247  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 248  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 249  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                  Notes  \
# 0    {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 1    {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 2    {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 3    {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 4    {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# ..                                                 ...
# 245  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 246  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 247  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 248  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 249  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
#
#                         name type                           stop  \
# 0       Länstrafik - Buss 21   ST  Göteborg Centralst Drottningt
# 1       Länstrafik - Buss 21   ST              Göteborg Nordstan
# 2     Länstrafik - Spårväg 2   ST  Göteborg Centralst Drottningt
# 3       Länstrafik - Buss 21   ST  Göteborg Centralst Drottningt
# 4       Länstrafik - Buss X1   ST              Göteborg Nordstan
# ..                       ...  ...                            ...
# 245  Länstrafik - Spårväg 11   ST  Göteborg Centralst Drottningt
# 246    Länstrafik - Buss 100   ST          Göteborg Åkareplatsen
# 247     Länstrafik - Buss 21   ST  Göteborg Centralst Drottningt
# 248     Länstrafik - Buss 21   ST              Göteborg Nordstan
# 249   Länstrafik - Spårväg 2   ST  Göteborg Centralst Drottningt
#
#                                                 stopid  stopExtId        lon  \
# 0    A=1@O=Göteborg Centralst Drottningt@X=11973740...  740030117  11.973740
# 1    A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  740015585  11.970791
# 2    A=1@O=Göteborg Centralst Drottningt@X=11973740...  740030117  11.973740
# 3    A=1@O=Göteborg Centralst Drottningt@X=11973740...  740030117  11.973740
# 4    A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  740015585  11.970791
# ..                                                 ...        ...        ...
# 245  A=1@O=Göteborg Centralst Drottningt@X=11973740...  740030117  11.973740
# 246  A=1@O=Göteborg Åkareplatsen@X=11975942@Y=57708...  740020490  11.975942
# 247  A=1@O=Göteborg Centralst Drottningt@X=11973740...  740030117  11.973740
# 248  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  740015585  11.970791
# 249  A=1@O=Göteborg Centralst Drottningt@X=11973740...  740030117  11.973740
#
#            lat      time        date  reachable                     direction  \
# 0    57.707898  11:43:00  2025-01-07       True          Göteborg Eketrägatan
# 1    57.709246  11:43:00  2025-01-07       True          Göteborg Eketrägatan
# 2    57.707898  11:43:00  2025-01-07       True            Mölndals Innerstad
# 3    57.707898  11:44:00  2025-01-07       True  Merkuriusgatan (Göteborg kn)
# 4    57.709246  11:44:00  2025-01-07       True   Hornkamsgatan (Göteborg kn)
# ..         ...       ...         ...        ...                           ...
# 245  57.707898  12:42:00  2025-01-07       True   Göteborg Saltholmens Brygga
# 246  57.708329  12:42:00  2025-01-07       True          Borås Centralstation
# 247  57.707898  12:43:00  2025-01-07       True          Göteborg Eketrägatan
# 248  57.709246  12:43:00  2025-01-07       True          Göteborg Eketrägatan
# 249  57.707898  12:43:00  2025-01-07       True            Mölndals Innerstad
#
#     directionFlag
# 0               2
# 1               2
# 2               1
# 3               1
# 4               1
# ..            ...
# 245             2
# 246             1
# 247             2
# 248             2
# 249             1
#
# [250 rows x 17 columns]
